# %% [markdown]
# Importing the data
# Exploring Imported Data
# 1. Overview of First Five Rows,
# 2. Summary Information,
# 3. Number And Percentage Of Missing Values BY Column,
# 4. Distribution of some Categorical Features Of Interest,
# 5. Distribution of Sale Price,
# 6. Numeric Features,
# 7. Drop Columns Without Useful Information,
# 8. Derive Neighborhood Information For Market Evaluation,
# 9. Save data,
# 10. Summary.

# %% [markdown]
# # Importing the Data

# %%
# import libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import io

# load and convert training and testing data to DataFrame
df_train = pd.read_csv(r'C:\Users\Sheng Miao\OneDrive\桌面\SpringBoard\Springboard_MyProjects\Capstone_Two\home-data-for-ml-course\train.csv')
df_test = pd.read_csv(r'C:\Users\Sheng Miao\OneDrive\桌面\SpringBoard\Springboard_MyProjects\Capstone_Two\home-data-for-ml-course\test.csv')

# %% [markdown]
# # Exploring Imported Data

# %% [markdown]
# ## 1. Overview of First Five Rows

# %%
# to print the first several rows of the data
pd.set_option('display.max_rows', None)
df_train.head().T
# Out:
#                      0        1        2        3        4
# Id                   1        2        3        4        5
# MSSubClass          60       20       60       70       60
# MSZoning            RL       RL       RL       RL       RL
# LotFrontage       65.0     80.0     68.0     60.0     84.0
# LotArea           8450     9600    11250     9550    14260
# Street            Pave     Pave     Pave     Pave     Pave
# Alley              NaN      NaN      NaN      NaN      NaN
# LotShape           Reg      Reg      IR1      IR1      IR1
# LandContour        Lvl      Lvl      Lvl      Lvl      Lvl
# Utilities       AllPub   AllPub   AllPub   AllPub   AllPub
# LotConfig       Inside      FR2   Inside   Corner      FR2
# LandSlope          Gtl      Gtl      Gtl      Gtl      Gtl
# Neighborhood   CollgCr  Veenker  CollgCr  Crawfor  NoRidge
# Condition1        Norm    Feedr     Norm     Norm     Norm
# Condition2        Norm     Norm     Norm     Norm     Norm
# BldgType          1Fam     1Fam     1Fam     1Fam     1Fam
# HouseStyle      2Story   1Story   2Story   2Story   2Story
# OverallQual          7        6        7        7        8
# OverallCond          5        8        5        5        5
# YearBuilt         2003     1976     2001     1915     2000
# YearRemodAdd      2003     1976     2002     1970     2000
# RoofStyle        Gable    Gable    Gable    Gable    Gable
# RoofMatl       CompShg  CompShg  CompShg  CompShg  CompShg
# Exterior1st    VinylSd  MetalSd  VinylSd  Wd Sdng  VinylSd
# Exterior2nd    VinylSd  MetalSd  VinylSd  Wd Shng  VinylSd
# MasVnrType     BrkFace      NaN  BrkFace      NaN  BrkFace
# MasVnrArea       196.0      0.0    162.0      0.0    350.0
# ExterQual           Gd       TA       Gd       TA       Gd
# ExterCond           TA       TA       TA       TA       TA
# Foundation       PConc   CBlock    PConc   BrkTil    PConc
# BsmtQual            Gd       Gd       Gd       TA       Gd
# BsmtCond            TA       TA       TA       Gd       TA
# BsmtExposure        No       Gd       Mn       No       Av
# BsmtFinType1       GLQ      ALQ      GLQ      ALQ      GLQ
# BsmtFinSF1         706      978      486      216      655
# BsmtFinType2       Unf      Unf      Unf      Unf      Unf
# BsmtFinSF2           0        0        0        0        0
# BsmtUnfSF          150      284      434      540      490
# TotalBsmtSF        856     1262      920      756     1145
# Heating           GasA     GasA     GasA     GasA     GasA
# HeatingQC           Ex       Ex       Ex       Gd       Ex
# CentralAir           Y        Y        Y        Y        Y
# Electrical       SBrkr    SBrkr    SBrkr    SBrkr    SBrkr
# 1stFlrSF           856     1262      920      961     1145
# 2ndFlrSF           854        0      866      756     1053
# LowQualFinSF         0        0        0        0        0
# GrLivArea         1710     1262     1786     1717     2198
# BsmtFullBath         1        0        1        1        1
# BsmtHalfBath         0        1        0        0        0
# FullBath             2        2        2        1        2
# HalfBath             1        0        1        0        1
# BedroomAbvGr         3        3        3        3        4
# KitchenAbvGr         1        1        1        1        1
# KitchenQual         Gd       TA       Gd       Gd       Gd
# TotRmsAbvGrd         8        6        6        7        9
# Functional         Typ      Typ      Typ      Typ      Typ
# Fireplaces           0        1        1        1        1
# FireplaceQu        NaN       TA       TA       Gd       TA
# GarageType      Attchd   Attchd   Attchd   Detchd   Attchd
# GarageYrBlt     2003.0   1976.0   2001.0   1998.0   2000.0
# GarageFinish       RFn      RFn      RFn      Unf      RFn
# GarageCars           2        2        2        3        3
# GarageArea         548      460      608      642      836
# GarageQual          TA       TA       TA       TA       TA
# GarageCond          TA       TA       TA       TA       TA
# PavedDrive           Y        Y        Y        Y        Y
# WoodDeckSF           0      298        0        0      192
# OpenPorchSF         61        0       42       35       84
# EnclosedPorch        0        0        0      272        0
# 3SsnPorch            0        0        0        0        0
# ScreenPorch          0        0        0        0        0
# PoolArea             0        0        0        0        0
# PoolQC             NaN      NaN      NaN      NaN      NaN
# Fence              NaN      NaN      NaN      NaN      NaN
# MiscFeature        NaN      NaN      NaN      NaN      NaN
# MiscVal              0        0        0        0        0
# MoSold               2        5        9        2       12
# YrSold            2008     2007     2008     2006     2008
# SaleType            WD       WD       WD       WD       WD
# SaleCondition   Normal   Normal   Normal  Abnorml   Normal
# SalePrice       208500   181500   223500   140000   250000

# %% [markdown]
# ## 2. Summary Information

# %%
# to see a summary of the train data
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
# to see a summary of the test data
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
#  17  OverallQual    1459 non-null   int64
#  18  OverallCond    1459 non-null   int64
#  19  YearBuilt      1459 non-null   int64
#  20  YearRemodAdd   1459 non-null   int64
#  21  RoofStyle      1459 non-null   object
#  22  RoofMatl       1459 non-null   object
#  23  Exterior1st    1458 non-null   object
#  24  Exterior2nd    1458 non-null   object
#  25  MasVnrType     565 non-null    object
#  26  MasVnrArea     1444 non-null   float64
#  27  ExterQual      1459 non-null   object
#  28  ExterCond      1459 non-null   object
#  29  Foundation     1459 non-null   object
#  30  BsmtQual       1415 non-null   object
#  31  BsmtCond       1414 non-null   object
#  32  BsmtExposure   1415 non-null   object
#  33  BsmtFinType1   1417 non-null   object
#  34  BsmtFinSF1     1458 non-null   float64
#  35  BsmtFinType2   1417 non-null   object
#  36  BsmtFinSF2     1458 non-null   float64
#  37  BsmtUnfSF      1458 non-null   float64
#  38  TotalBsmtSF    1458 non-null   float64
#  39  Heating        1459 non-null   object
#  40  HeatingQC      1459 non-null   object
#  41  CentralAir     1459 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1459 non-null   int64
#  44  2ndFlrSF       1459 non-null   int64
#  45  LowQualFinSF   1459 non-null   int64
#  46  GrLivArea      1459 non-null   int64
#  47  BsmtFullBath   1457 non-null   float64
#  48  BsmtHalfBath   1457 non-null   float64
#  49  FullBath       1459 non-null   int64
#  50  HalfBath       1459 non-null   int64
#  51  BedroomAbvGr   1459 non-null   int64
#  52  KitchenAbvGr   1459 non-null   int64
#  53  KitchenQual    1458 non-null   object
#  54  TotRmsAbvGrd   1459 non-null   int64
#  55  Functional     1457 non-null   object
#  56  Fireplaces     1459 non-null   int64
#  57  FireplaceQu    729 non-null    object
#  58  GarageType     1383 non-null   object
#  59  GarageYrBlt    1381 non-null   float64
#  60  GarageFinish   1381 non-null   object
#  61  GarageCars     1458 non-null   float64
#  62  GarageArea     1458 non-null   float64
#  63  GarageQual     1381 non-null   object
#  64  GarageCond     1381 non-null   object
#  65  PavedDrive     1459 non-null   object
#  66  WoodDeckSF     1459 non-null   int64
#  67  OpenPorchSF    1459 non-null   int64
#  68  EnclosedPorch  1459 non-null   int64
#  69  3SsnPorch      1459 non-null   int64
#  70  ScreenPorch    1459 non-null   int64
#  71  PoolArea       1459 non-null   int64
#  72  PoolQC         3 non-null      object
#  73  Fence          290 non-null    object
#  74  MiscFeature    51 non-null     object
#  75  MiscVal        1459 non-null   int64
#  76  MoSold         1459 non-null   int64
#  77  YrSold         1459 non-null   int64
#  78  SaleType       1458 non-null   object
#  79  SaleCondition  1459 non-null   object
# dtypes: float64(11), int64(26), object(43)
# memory usage: 912.0+ KB

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Group features into major categories
feature_groups = {
    "General Property Info": [
        "MSSubClass", "MSZoning", "LotFrontage", "LotArea", "Street", "Alley", "LotShape", "LandContour", "Utilities", 
        "LotConfig", "LandSlope", "Neighborhood", "Condition1", "Condition2"
    ],
    "Building Type & Style": [
        "BldgType", "HouseStyle"
    ],
    "Overall Quality & Condition": [
        "OverallQual", "OverallCond"
    ],
    "Construction & Remodeling": [
        "YearBuilt", "YearRemodAdd"
    ],
    "Roof & Exterior": [
        "RoofStyle", "RoofMatl", "Exterior1st", "Exterior2nd", "MasVnrType", "MasVnrArea", "ExterQual", "ExterCond"
    ],
    "Foundation & Basement": [
        "Foundation", "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinSF1", 
        "BsmtFinType2", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF"
    ],
    "Heating & Cooling": [
        "Heating", "HeatingQC", "CentralAir", "Electrical"
    ],
    "Interior Space": [
        "1stFlrSF", "2ndFlrSF", "LowQualFinSF", "GrLivArea", "TotRmsAbvGrd", "Functional"
    ],
    "Bathrooms & Bedrooms": [
        "BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath", "Bedroom", "Kitchen", "KitchenQual"
    ],
    "Fireplaces": [
        "Fireplaces", "FireplaceQu"
    ],
    "Garage": [
        "GarageType", "GarageYrBlt", "GarageFinish", "GarageCars", "GarageArea", "GarageQual", "GarageCond"
    ],
    "Porches & Decks": [
        "PavedDrive", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch"
    ],
    "Extra Amenities": [
        "PoolArea", "PoolQC", "Fence", "MiscFeature", "MiscVal"
    ],
    "Sales Info": [
        "MoSold", "YrSold", "SaleType", "SaleCondition"
    ]
}

# Count number of features in each group
category_counts = {category: len(features) for category, features in feature_groups.items()}


# Plotting the pie chart with requested changes
plt.figure(figsize=(10, 10))
plt.pie(
    category_counts.values(),
    labels=category_counts.keys(),
    startangle=140,
    labeldistance=1.05,
    textprops={'fontsize': 14}  # Increase font size of category labels
)
plt.text(0, 1.2, "Main Categories of 79 features ", ha='center', fontsize=20)
plt.axis('equal')
plt.savefig('Main_Categories_of_79_features.jpg', dpi=300, bbox_inches="tight")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Number And Percentage Of Missing Values BY Column

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(df_train.isnull(), cbar=False)
plt.xticks(rotation=90)
plt.show()

# %%
# count missing values of train data
print("Train data_summary on missing values")
pd.set_option('display.max_rows', None)
train_missing = pd.concat([df_train.isna().sum(), 100 * df_train.isna().mean()], axis=1)
train_missing.columns=['count', '%']
train_missing.sort_values(by='count')
# Out:
# Train data_summary on missing values
#                count          %
# Id                 0   0.000000
# TotalBsmtSF        0   0.000000
# Heating            0   0.000000
# SaleCondition      0   0.000000
# CentralAir         0   0.000000
# 1stFlrSF           0   0.000000
# 2ndFlrSF           0   0.000000
# LowQualFinSF       0   0.000000
# GrLivArea          0   0.000000
# BsmtFullBath       0   0.000000
# BsmtHalfBath       0   0.000000
# FullBath           0   0.000000
# HalfBath           0   0.000000
# BedroomAbvGr       0   0.000000
# KitchenAbvGr       0   0.000000
# KitchenQual        0   0.000000
# TotRmsAbvGrd       0   0.000000
# Functional         0   0.000000
# SaleType           0   0.000000
# YrSold             0   0.000000
# MoSold             0   0.000000
# MiscVal            0   0.000000
# PoolArea           0   0.000000
# ScreenPorch        0   0.000000
# BsmtUnfSF          0   0.000000
# 3SsnPorch          0   0.000000
# OpenPorchSF        0   0.000000
# WoodDeckSF         0   0.000000
# PavedDrive         0   0.000000
# GarageArea         0   0.000000
# GarageCars         0   0.000000
# Fireplaces         0   0.000000
# EnclosedPorch      0   0.000000
# BsmtFinSF2         0   0.000000
# HeatingQC          0   0.000000
# SalePrice          0   0.000000
# Utilities          0   0.000000
# LandContour        0   0.000000
# Neighborhood       0   0.000000
# Condition1         0   0.000000
# LotShape           0   0.000000
# Street             0   0.000000
# LotArea            0   0.000000
# BsmtFinSF1         0   0.000000
# Condition2         0   0.000000
# BldgType           0   0.000000
# HouseStyle         0   0.000000
# OverallQual        0   0.000000
# OverallCond        0   0.000000
# YearBuilt          0   0.000000
# YearRemodAdd       0   0.000000
# RoofStyle          0   0.000000
# RoofMatl           0   0.000000
# Exterior1st        0   0.000000
# Exterior2nd        0   0.000000
# MSZoning           0   0.000000
# ExterQual          0   0.000000
# ExterCond          0   0.000000
# Foundation         0   0.000000
# MSSubClass         0   0.000000
# LandSlope          0   0.000000
# LotConfig          0   0.000000
# Electrical         1   0.068493
# MasVnrArea         8   0.547945
# BsmtQual          37   2.534247
# BsmtCond          37   2.534247
# BsmtFinType1      37   2.534247
# BsmtFinType2      38   2.602740
# BsmtExposure      38   2.602740
# GarageQual        81   5.547945
# GarageFinish      81   5.547945
# GarageYrBlt       81   5.547945
# GarageType        81   5.547945
# GarageCond        81   5.547945
# LotFrontage      259  17.739726
# FireplaceQu      690  47.260274
# MasVnrType       872  59.726027
# Fence           1179  80.753425
# Alley           1369  93.767123
# MiscFeature     1406  96.301370
# PoolQC          1453  99.520548

# %%
# count missing values of test data
print("Test data_summary on missing values")
pd.set_option('display.max_rows', None)
missing_test = pd.concat([df_test.isna().sum(), 100 * df_test.isna().mean()], axis=1)
missing_test.columns = ['count', '%']
missing_test.sort_values(by='count')
# Out:
# Test data_summary on missing values
#                count          %
# Id                 0   0.000000
# Foundation         0   0.000000
# HeatingQC          0   0.000000
# CentralAir         0   0.000000
# Electrical         0   0.000000
# 1stFlrSF           0   0.000000
# 2ndFlrSF           0   0.000000
# LowQualFinSF       0   0.000000
# GrLivArea          0   0.000000
# FullBath           0   0.000000
# HalfBath           0   0.000000
# BedroomAbvGr       0   0.000000
# ExterCond          0   0.000000
# KitchenAbvGr       0   0.000000
# Fireplaces         0   0.000000
# PavedDrive         0   0.000000
# WoodDeckSF         0   0.000000
# OpenPorchSF        0   0.000000
# EnclosedPorch      0   0.000000
# 3SsnPorch          0   0.000000
# ScreenPorch        0   0.000000
# PoolArea           0   0.000000
# MiscVal            0   0.000000
# MoSold             0   0.000000
# YrSold             0   0.000000
# TotRmsAbvGrd       0   0.000000
# ExterQual          0   0.000000
# Heating            0   0.000000
# SaleCondition      0   0.000000
# OverallQual        0   0.000000
# OverallCond        0   0.000000
# YearBuilt          0   0.000000
# YearRemodAdd       0   0.000000
# RoofStyle          0   0.000000
# RoofMatl           0   0.000000
# Condition2         0   0.000000
# Condition1         0   0.000000
# BldgType           0   0.000000
# Neighborhood       0   0.000000
# LotConfig          0   0.000000
# LandContour        0   0.000000
# LotShape           0   0.000000
# Street             0   0.000000
# LotArea            0   0.000000
# MSSubClass         0   0.000000
# LandSlope          0   0.000000
# HouseStyle         0   0.000000
# GarageCars         1   0.068540
# GarageArea         1   0.068540
# KitchenQual        1   0.068540
# Exterior1st        1   0.068540
# SaleType           1   0.068540
# TotalBsmtSF        1   0.068540
# BsmtUnfSF          1   0.068540
# Exterior2nd        1   0.068540
# BsmtFinSF1         1   0.068540
# BsmtFinSF2         1   0.068540
# BsmtFullBath       2   0.137080
# Utilities          2   0.137080
# Functional         2   0.137080
# BsmtHalfBath       2   0.137080
# MSZoning           4   0.274160
# MasVnrArea        15   1.028101
# BsmtFinType2      42   2.878684
# BsmtFinType1      42   2.878684
# BsmtQual          44   3.015764
# BsmtExposure      44   3.015764
# BsmtCond          45   3.084304
# GarageType        76   5.209047
# GarageCond        78   5.346127
# GarageQual        78   5.346127
# GarageFinish      78   5.346127
# GarageYrBlt       78   5.346127
# LotFrontage      227  15.558602
# FireplaceQu      730  50.034270
# MasVnrType       894  61.274846
# Fence           1169  80.123372
# Alley           1352  92.666210
# MiscFeature     1408  96.504455
# PoolQC          1456  99.794380

# %%
# Extracting information into a tabular form
info_df_train = pd.DataFrame({
    'Train_Column': df_train.columns,
    'Train_NullCount': df_train.isnull().sum(),
    'Train_isnull(%)':df_train.isnull().mean() * 100,
    'Train_DataType': df_train.dtypes
})

info_df_test = pd.DataFrame({
    'Test_Column': df_test.columns,
    'Test_NullCount': df_test.isnull().sum(),
    'Test_isnull(%)':df_test.isnull().mean() * 100,
    'Test_DataType': df_test.dtypes
})

# Export to CSV
info_df_train.to_csv('Train_isnull.csv', index=False)
info_df_test.to_csv('Test_isnull.csv', index=False)

# %% [markdown]
# #### In both train and test data, collumns 'Alley', 'PoolQC' and 'MiscFeature' have more than 90% of missing values. column 'fence' has missing values above 80%, and more than half values in 'FireplaceQu' and 'MasVnrTyre' are missing.

# %% [markdown]
# ## 4.  Univariate Distribution of some Categorical Features Of Interest

# %% [markdown]
# ### 4.1 Targe SalePrice

# %%
### 4.7 Univariate chart of the target--SalePrice
plt.figure(figsize=(10, 6))
sns.histplot(df_train['SalePrice'], bins=10)
plt.title("SalePrice Distribution (USD)", fontsize=16)
plt.xlabel("Sale Price ($)", fontsize=14)
plt.ylabel("Frequency", fontsize=14)

# Ensure the "figures" directory exists
figures_dir = "figures"
os.makedirs(figures_dir, exist_ok=True)

plt.savefig(os.path.join(figures_dir,'SalePrice_distribution.jpg'), dpi=300, bbox_inches="tight")

plt.show()

# %% [markdown]
# ### 4.2 Zoning Classification

# %%
# count the number and percentage of each Zoning classification of the train data
MSZoning_train = pd.concat([df_train['MSZoning'].value_counts(), 100 * df_train['MSZoning'].value_counts()/1460], axis=1)
MSZoning_train.columns = ['count', '%']
MSZoning_train.sort_values(by='count', ascending=False)
# Out:
#           count          %
# MSZoning
# RL         1151  78.835616
# RM          218  14.931507
# FV           65   4.452055
# RH           16   1.095890
# C (all)      10   0.684932

# %%
# count the number and percentage of each Zoning classification of the test data
MSZoning_test = pd.concat([df_test['MSZoning'].value_counts(), 100 * df_test['MSZoning'].value_counts()/1460], axis=1)
MSZoning_test.columns = ['count', '%']
MSZoning_test.sort_values(by='count', ascending=False)
# Out:
#           count          %
# MSZoning
# RL         1114  76.301370
# RM          242  16.575342
# FV           74   5.068493
# C (all)      15   1.027397
# RH           10   0.684932

# %%
# create barplot to see the distribution of Zoning Classification of the train data
plt.figure(figsize=(10, 6))
sns.histplot(df_train['MSZoning'])
plt.title("Univariate Distribution of MSZoning")
plt.xlabel("MSZoning")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### The top two zoning classification account for vast majority of total records. RL (Residential Low Density) account for more than 75%, and RM (Residential Medium Density) account for about 15%.

# %% [markdown]
# ### 4.3 Type of Dwelling

# %%
# count the number and percentage of each type of dwelling of the train data
MSSubClass_train = pd.concat([df_train['MSSubClass'].value_counts(), 100 * df_train['MSSubClass'].value_counts()/1460], axis=1)
MSSubClass_train.columns = ['count', '%']
MSSubClass_train.sort_values(by='count', ascending=False)
# Out:
#             count          %
# MSSubClass
# 20            536  36.712329
# 60            299  20.479452
# 50            144   9.863014
# 120            87   5.958904
# 30             69   4.726027
# 160            63   4.315068
# 70             60   4.109589
# 80             58   3.972603
# 90             52   3.561644
# 190            30   2.054795
# 85             20   1.369863
# 75             16   1.095890
# 45             12   0.821918
# 180            10   0.684932
# 40              4   0.273973

# %%
# count the number and percentage of each type of dwelling of the test data
MSSubClass_test = pd.concat([df_test['MSSubClass'].value_counts(), 100 * df_test['MSSubClass'].value_counts()/1460], axis=1)
MSSubClass_test.columns = ['count', '%']
MSSubClass_test.sort_values(by='count', ascending=False)
# Out:
#             count          %
# MSSubClass
# 20            543  37.191781
# 60            276  18.904110
# 50            143   9.794521
# 120            95   6.506849
# 30             70   4.794521
# 70             68   4.657534
# 160            65   4.452055
# 80             60   4.109589
# 90             57   3.904110
# 190            31   2.123288
# 85             28   1.917808
# 75              7   0.479452
# 180             7   0.479452
# 45              6   0.410959
# 40              2   0.136986
# 150             1   0.068493

# %%
# create barplot to see the distribution of Dwelling types of the train data
plt.figure(figsize=(10, 6))
sns.histplot(df_train['MSSubClass'], bins=15)
plt.title("Univariate Distribution of MSSubClass")
plt.xlabel("MSSubClass")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 4.4 Neighborhood

# %%
# count the number and percentage of each Neighborhood of the train data
Neighborhood_train = pd.concat([df_train['Neighborhood'].value_counts(), 100 * df_train['Neighborhood'].value_counts()/1460], axis=1)
Neighborhood_train.columns = ['count', '%']
Neighborhood_train.sort_values(by='count', ascending=False)
# Out:
#               count          %
# Neighborhood
# NAmes           225  15.410959
# CollgCr         150  10.273973
# OldTown         113   7.739726
# Edwards         100   6.849315
# Somerst          86   5.890411
# Gilbert          79   5.410959
# NridgHt          77   5.273973
# Sawyer           74   5.068493
# NWAmes           73   5.000000
# SawyerW          59   4.041096
# BrkSide          58   3.972603
# Crawfor          51   3.493151
# Mitchel          49   3.356164
# NoRidge          41   2.808219
# Timber           38   2.602740
# IDOTRR           37   2.534247
# ClearCr          28   1.917808
# StoneBr          25   1.712329
# SWISU            25   1.712329
# MeadowV          17   1.164384
# Blmngtn          17   1.164384
# BrDale           16   1.095890
# Veenker          11   0.753425
# NPkVill           9   0.616438
# Blueste           2   0.136986

# %%
# create barplot to see the distribution of Neighborhoods of the train data
plt.figure(figsize=(10, 6))
sns.histplot(df_train['Neighborhood'], bins=12)
plt.title("Univariate Distribution of Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Frequency")
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### 4.5 Month Sold (MM)

# %%
# create barplot to see the distribution of Month Sale of the train data
plt.figure(figsize=(10, 6))
sns.histplot(df_train['MoSold'], bins=12)
plt.title("Univariate Distribution of Month Sale (MM)")
plt.xlabel("Month")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 4.6 Type of Sale

# %%
# create barplot to see the distribution of Sale Types of the train data
plt.figure(figsize=(10, 6))
sns.histplot(df_train['SaleType'])
plt.title("Univariate Distribution of SaleType")
plt.xlabel("Sale Type")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 4.7 Condition of Sale

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df_train['SaleCondition'])
plt.title("Univariate Distribution of SaleCondition")
plt.xlabel("Sale Condition")
plt.ylabel("Frequency")
plt.show()

# %%
# create subplots using matplotlib's subplots
fig, ax = plt.subplots(4, 2, figsize=(15, 25))
sns.histplot(df_train['SalePrice'], ax=ax[0,0])
ax[0, 0].set_title('SalePrice in Train Data')
ax[0, 0].set_xlabel('SalePrice')
ax[0, 0].set_ylabel('Frequency')
sns.histplot(df_train['MSZoning'], ax=ax[0, 1])
ax[0, 1].set_title('Zoning Classification in Train Data')
ax[0, 1].set_xlabel('Zoning Classification')
ax[0, 1].set_ylabel('Frequency')
sns.histplot(df_train['MSSubClass'], ax=ax[1, 0])
ax[1, 0].set_title('Type of Dwelling in Train Data')
ax[1, 0].set_xlabel('Type of Dwelling')
ax[1, 0].set_ylabel('Frequency')
sns.histplot(df_train['Neighborhood'], ax=ax[1, 1])
ax[1, 1].set_title('Neighborhood in Train Data')
ax[1, 1].set_xlabel('Neighborhood')
ax[1, 1].set_ylabel('Frequency')
ax[1, 1].tick_params(axis='x', rotation=45, labelright=True, labelleft=False)
sns.histplot(df_train['MoSold'], ax=ax[2, 0])
ax[2, 0].set_title('Month Sale (MM) in Train Data')
ax[2, 0].set_xlabel('Month Sale (MM)')
ax[2, 0].set_ylabel('Frequency')
sns.histplot(df_train['SaleType'], ax=ax[2, 1])
ax[2, 1].set_title('Type of Sale in Train Data')
ax[2, 1].set_xlabel('Type of Sale')
ax[2, 1].set_ylabel('Frequency')
sns.histplot(df_train['SaleCondition'], ax=ax[3, 0])
ax[3, 0].set_title('Sale Condition in Train Data')
ax[3, 0].set_xlabel('Sale Condition')
ax[3, 0].set_ylabel('Frequency')

fig.delaxes(ax[3, 1])

# plt.subplots_adjust(wspace=0.15, hspace=0.33)
plt.tight_layout()

plt.savefig(os.path.join(figures_dir,'Univariate Distribution of some Categorical Features Of Interest.jpg'), dpi=300, bbox_inches="tight")

# %% [markdown]
# I analyzed the distribution of records in the train dataset, focusing on six features of interest, all of which showed significantly biased distribution. For Zoning Classification, the vast majority of records belong to RL (Residential Low Density) and RM (Residential Medium Density). Similarly, for Type of Sale, most transactions are categorized as WD (Warranty Deed - Conventional), and for Sale condition, "Normal" accounts for the majority of records. In contrast, the distributions of Type of Dwelling, Neighborhood, and Month sale (MM) are more varied. The top three dwelling types are 20 (1-STORY 1946 & NEWER ALL STYLES), 60 (2-STORY 1946 & NEWER) and 50 (1-1/2 STORY FINISHED ALL AGES). The most common neighborhoods are NAmes, CollgCr and OldTown. Interestingly, there is a clear seasonal trend in the sales data: June, July and May are the busiest months, while Feb, Jan and Dec see the fewest sales.

# %% [markdown]
# ## 5. Bivariate charts with Sale Price

# %% [markdown]
# ### 5.1 Neighborhood vs. SalePrice

# %%
# Average Sale price of each neighborhood of the train data
Nb_price_means = df_train.groupby('Neighborhood')['SalePrice'].mean().sort_values(ascending=False)
print(Nb_price_means)
# Out:
# Neighborhood
# NoRidge    335295.317073
# NridgHt    316270.623377
# StoneBr    310499.000000
# Timber     242247.447368
# Veenker    238772.727273
# Somerst    225379.837209
# ClearCr    212565.428571
# Crawfor    210624.725490
# CollgCr    197965.773333
# Blmngtn    194870.882353
# Gilbert    192854.506329
# NWAmes     189050.068493
# SawyerW    186555.796610
# Mitchel    156270.122449
# NAmes      145847.080000
# NPkVill    142694.444444
# SWISU      142591.360000
# Blueste    137500.000000
# Sawyer     136793.135135
# OldTown    128225.300885
# Edwards    128219.700000
# BrkSide    124834.051724
# BrDale     104493.750000
# IDOTRR     100123.783784
# MeadowV     98576.470588
# Name: SalePrice, dtype: float64

# %%
mean_order = df_train.groupby('Neighborhood')['SalePrice'].mean().sort_values(ascending=True).index
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_train['Neighborhood'], y=df_train['SalePrice'], order=mean_order)
plt.xlabel('Neighborhood')
plt.ylabel('Price($)')
plt.xticks(rotation=45, ha='right')

plt.savefig(os.path.join(figures_dir,'Sale Price by Neighborhood.jpg'), dpi=300, bbox_inches="tight")

# %% [markdown]
# ### 5.2 Type of Dwelling  vs. SalePrice

# %%
mean_order = df_train.groupby('MSSubClass')['SalePrice'].mean().sort_values(ascending=True).index
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_train['MSSubClass'], y=df_train['SalePrice'], order=mean_order)
plt.xlabel('MSSubClass')
plt.ylabel('Price($)')
plt.xticks(rotation=45, ha='right')

plt.savefig(os.path.join(figures_dir,'Sale Price by MSSubClass.jpg'), dpi=300, bbox_inches="tight")

# %% [markdown]
# ### 5.3 Zoning Classification vs. SalePrice

# %%
mean_order = df_train.groupby('MSZoning')['SalePrice'].mean().sort_values(ascending=True).index
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_train['MSZoning'], y=df_train['SalePrice'], order=mean_order)
plt.xlabel('MSZoning')
plt.ylabel('Price($)')
plt.xticks(rotation=45, ha='right')

plt.savefig(os.path.join(figures_dir,'Sale Price by MSZoning.jpg'), dpi=300, bbox_inches="tight")

# %% [markdown]
# ### 5.4 Month Sale vs. SalePrice

# %%
# create barplot of average Sale price of each Month Sale of the train data
df_train.groupby('MoSold')['SalePrice'].mean().sort_values(ascending=True).plot(kind='barh', figsize=(5, 5), title='Sale Price by Month Sale (MM)')
plt.xlabel('Price($)')
# Out:
# Text(0.5, 0, 'Price($)')

# %%
mean_order = df_train.groupby('MoSold')['SalePrice'].mean().sort_values(ascending=True).index
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_train['MoSold'], y=df_train['SalePrice'], order=mean_order)
plt.xlabel('MoSold')
plt.ylabel('Price($)')
plt.xticks(rotation=45, ha='right')

plt.savefig(os.path.join(figures_dir,'Sale Price by MoSold.jpg'), dpi=300, bbox_inches="tight")

# %% [markdown]
# ### 5.5 Type of Sale vs. SalePrice

# %%
mean_order = df_train.groupby('SaleType')['SalePrice'].mean().sort_values(ascending=True).index
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_train['SaleType'], y=df_train['SalePrice'], order=mean_order)
plt.xlabel('SaleType')
plt.ylabel('Price($)')
plt.xticks(rotation=45, ha='right')

plt.savefig(os.path.join(figures_dir,'Sale Price by SaleType.jpg'), dpi=300, bbox_inches="tight")

# %% [markdown]
# ### 5.6 Sale Condition vs. SalePrice

# %%
mean_order = df_train.groupby('SaleCondition')['SalePrice'].mean().sort_values(ascending=True).index
plt.figure(figsize=(10, 6))
sns.boxplot(x=df_train['SaleCondition'], y=df_train['SalePrice'], order=mean_order)
plt.xlabel('SaleCondition')
plt.ylabel('Price($)')
plt.xticks(rotation=45, ha='right')

plt.savefig(os.path.join(figures_dir,'Sale Price by SaleCondition.jpg'), dpi=300, bbox_inches="tight")

# %%
help()
# Out:
# Welcome to Python 3.12's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.12/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q" or "quit".
#
#
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
# create six subplots using matplotlib's subplots
fig, ax = plt.subplots(3, 2, figsize=(15, 20))

mean_order = df_train.groupby('MSZoning')['SalePrice'].mean().sort_values(ascending=True).index
sns.boxplot(x=df_train['MSZoning'], y=df_train['SalePrice'], order=mean_order, ax=ax[0, 0])
ax[0, 0].set_title('Zoning Classification vs. Sale Price')
ax[0, 0].set_xlabel('MSZoning')
ax[0, 0].set_ylabel('Price($)')
ax[0, 0].tick_params(axis='x', rotation=45, labelright=True, labelleft=False)

mean_order = df_train.groupby('MSSubClass')['SalePrice'].mean().sort_values(ascending=True).index
sns.boxplot(x=df_train['MSSubClass'], y=df_train['SalePrice'], order=mean_order, ax=ax[0, 1])
ax[0, 1].set_title('Type of Dwelling vs. Sale Price')
ax[0, 1].set_xlabel('MSSubClass')
ax[0, 1].set_ylabel('Price($)')
ax[0, 0].tick_params(axis='x', rotation=45, labelright=True, labelleft=False)

mean_order = df_train.groupby('Neighborhood')['SalePrice'].mean().sort_values(ascending=True).index
sns.boxplot(x=df_train['Neighborhood'], y=df_train['SalePrice'], order=mean_order, ax=ax[1, 0])
ax[1, 0].set_title('Neighborhood vs. Sale Price')
ax[1, 0].set_xlabel('Neighborhood')
ax[1, 0].set_ylabel('Price($)')
ax[1, 0].tick_params(axis='x', rotation=45, labelright=True, labelleft=False)

mean_order = df_train.groupby('MoSold')['SalePrice'].mean().sort_values(ascending=True).index
sns.boxplot(x=df_train['MoSold'], y=df_train['SalePrice'], order=mean_order, ax=ax[1, 1])
ax[1, 1].set_title('Month Sale (MM) vs. Sale Price')
ax[1, 1].set_xlabel('MoSold')
ax[1, 1].set_ylabel('Price($)')
ax[1, 1].tick_params(axis='x', rotation=45, labelright=True, labelleft=False)

mean_order = df_train.groupby('SaleType')['SalePrice'].mean().sort_values(ascending=True).index
sns.boxplot(x=df_train['SaleType'], y=df_train['SalePrice'], order=mean_order, ax=ax[2, 0])
ax[2, 0].set_title('Type of Sale vs. Sale Price')
ax[2, 0].set_xlabel('SaleType')
ax[2, 0].set_ylabel('Price($)')
ax[2, 0].tick_params(axis='x', rotation=45, labelright=True, labelleft=False)

mean_order = df_train.groupby('SaleCondition')['SalePrice'].mean().sort_values(ascending=True).index
sns.boxplot(x=df_train['SaleCondition'], y=df_train['SalePrice'], order=mean_order, ax=ax[2, 1])
ax[2, 1].set_title('Sale Condition vs. Sale Price')
ax[2, 1].set_xlabel('SaleCondition')
ax[2, 1].set_ylabel('Price($)')
ax[2, 1].tick_params(axis='x', rotation=45, labelright=True, labelleft=False)

# plt.subplots_adjust(wspace=0.3, hspace=0.2)
plt.tight_layout()

plt.savefig(os.path.join(figures_dir,'Bivariate charts with Sale Price.jpg'), dpi=300, bbox_inches="tight")

# %% [markdown]
# All six features of interest impact the sale price. Among Zoning Classes, FV(Floating Village Residential), RL(Residential Low Density) and RH(Residential High Density) are assocated with the highest prices. For Dwelling Types, the top three are 60(2-STORY 1946 & NEWER), 120(1-STORY PUD (Planned Unit Development) - 1946 & NEWER), 75(2-1/2 STORY ALL AGES). In terms of Neighborhood, NoRidge, NridgHt and StoneBr consistently have the highest porperty values. While the seasonal factor doesn't appear to significantly affect sale prices, the data shows that prices tend to peak in Sep, Nov and Dec and are lowest in June, May and April. Regarding Sale Types, New (Home just constructed and sold) and Con (Contract 15% Down payment regular terms) command higher prices than other categories. Notablly, homes classified under the Sale Condition "Partial" (Home was not completed when last assessed) have the highest sale prices, which contradicts common expectations. This finding is quite surprising and unusual.

# %% [markdown]
# ## 6. Numeric Features

# %% [markdown]
# ### 6.1 Numeric Data Summary

# %%
# call 'describe' method for a statistical summary of the numerical columns and display the transpose
df_train.describe().transpose()
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# TotalBsmtSF    1460.0    1057.429452    438.705324      0.0     795.75
# 1stFlrSF       1460.0    1162.626712    386.587738    334.0     882.00
# 2ndFlrSF       1460.0     346.992466    436.528436      0.0       0.00
# LowQualFinSF   1460.0       5.844521     48.623081      0.0       0.00
# GrLivArea      1460.0    1515.463699    525.480383    334.0    1129.50
# BsmtFullBath   1460.0       0.425342      0.518911      0.0       0.00
# BsmtHalfBath   1460.0       0.057534      0.238753      0.0       0.00
# FullBath       1460.0       1.565068      0.550916      0.0       1.00
# HalfBath       1460.0       0.382877      0.502885      0.0       0.00
# BedroomAbvGr   1460.0       2.866438      0.815778      0.0       2.00
# KitchenAbvGr   1460.0       1.046575      0.220338      0.0       1.00
# TotRmsAbvGrd   1460.0       6.517808      1.625393      2.0       5.00
# Fireplaces     1460.0       0.613014      0.644666      0.0       0.00
# GarageYrBlt    1379.0    1978.506164     24.689725   1900.0    1961.00
# GarageCars     1460.0       1.767123      0.747315      0.0       1.00
# GarageArea     1460.0     472.980137    213.804841      0.0     334.50
# WoodDeckSF     1460.0      94.244521    125.338794      0.0       0.00
# OpenPorchSF    1460.0      46.660274     66.256028      0.0       0.00
# EnclosedPorch  1460.0      21.954110     61.119149      0.0       0.00
# 3SsnPorch      1460.0       3.409589     29.317331      0.0       0.00
# ScreenPorch    1460.0      15.060959     55.757415      0.0       0.00
# PoolArea       1460.0       2.758904     40.177307      0.0       0.00
# MiscVal        1460.0      43.489041    496.123024      0.0       0.00
# MoSold         1460.0       6.321918      2.703626      1.0       5.00
# YrSold         1460.0    2007.815753      1.328095   2006.0    2007.00
# SalePrice      1460.0  180921.195890  79442.502883  34900.0  129975.00
#
#                     50%        75%       max
# Id                730.5    1095.25    1460.0
# MSSubClass         50.0      70.00     190.0
# LotFrontage        69.0      80.00     313.0
# LotArea          9478.5   11601.50  215245.0
# OverallQual         6.0       7.00      10.0
# OverallCond         5.0       6.00       9.0
# YearBuilt        1973.0    2000.00    2010.0
# YearRemodAdd     1994.0    2004.00    2010.0
# MasVnrArea          0.0     166.00    1600.0
# BsmtFinSF1        383.5     712.25    5644.0
# BsmtFinSF2          0.0       0.00    1474.0
# BsmtUnfSF         477.5     808.00    2336.0
# TotalBsmtSF       991.5    1298.25    6110.0
# 1stFlrSF         1087.0    1391.25    4692.0
# 2ndFlrSF            0.0     728.00    2065.0
# LowQualFinSF        0.0       0.00     572.0
# GrLivArea        1464.0    1776.75    5642.0
# BsmtFullBath        0.0       1.00       3.0
# BsmtHalfBath        0.0       0.00       2.0
# FullBath            2.0       2.00       3.0
# HalfBath            0.0       1.00       2.0
# BedroomAbvGr        3.0       3.00       8.0
# KitchenAbvGr        1.0       1.00       3.0
# TotRmsAbvGrd        6.0       7.00      14.0
# Fireplaces          1.0       1.00       3.0
# GarageYrBlt      1980.0    2002.00    2010.0
# GarageCars          2.0       2.00       4.0
# GarageArea        480.0     576.00    1418.0
# WoodDeckSF          0.0     168.00     857.0
# OpenPorchSF        25.0      68.00     547.0
# EnclosedPorch       0.0       0.00     552.0
# 3SsnPorch           0.0       0.00     508.0
# ScreenPorch         0.0       0.00     480.0
# PoolArea            0.0       0.00     738.0
# MiscVal             0.0       0.00   15500.0
# MoSold              6.0       8.00      12.0
# YrSold           2008.0    2009.00    2010.0
# SalePrice      163000.0  214000.00  755000.0

# %%
# call 'hist' method to plot histograms of each of the numeric features
df_train.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.9)


plt.savefig(os.path.join(figures_dir,'Numeric Feature hist.jpg'), dpi=300, bbox_inches="tight")

# %% [markdown]
# ## 7. Drop Columns Without Useful Information

# %%
# Drop off columns with more than 50% of the records missing
df_train.drop(columns=['PoolQC', 'Alley', 'MiscFeature', 'Fence', 'MasVnrType', 'FireplaceQu'], inplace=True)
df_test.drop(columns=['PoolQC', 'Alley', 'MiscFeature', 'Fence', 'MasVnrType', 'FireplaceQu'], inplace=True);

# %% [markdown]
# ## 8. Derive Neighborhood Information For Market Evaluation

# %% [markdown]
# Based on our business knowledge, we know that factors such as neighborhood-wide supply and demand, safety, school rankings, and the envionment can significantly influence sale price. Therefore, it's essential to incorporate statistic information about each neighborhood in Ames, Iowa--such as population, area, safety, school rankings--into our dataset.

# %% [markdown]
# The data includes 25 Neighborhoods in Ames, IA, but many of these names do not match the 27 neighborhoods listed on the City of Ames Neighborhood Associations Map (https://www.cityofames.org/home/showpublisheddocument/52755/637050278030900000). Using Google Maps, we observed a clear geographical pattern between neighborboods with the highest and lowest sale prices. The top five neighborhoods with the highest sale prices are located in the northwest part of Ames, while the neighborhoods with the lowest sale prices are primarily distributed in the city's central area  where the old town is situated, as well as in the southeast part of the city.

# %% [markdown]
# ## 9. Save data

# %%
#current_dir = os.getcwd()
#df_train.to_csv(os.path.join(current_dir, "df_train_cleaned.csv"), index=False)
#df_test.to_csv(os.path.join(current_dir, "df_test_cleaned.csv"), index=False)

# %%
import dill

with open("Capstone Two_Data Wrangling.pkl", "wb") as f:
    dill.dump_session(f)

# %% [markdown]
# ## 10. Summary

# %% [markdown]
# 1. Both train and test datasets demonstrate good integrity. Out of 79 variables, 45 have no missing values in either dataset. 16 variables have fewer than 5 missing values. However, several variables contain substantial amounts of missing data: "PoolQC"(~99%), "MiscFeature"(~96%), "Alley"(~93%), "Fence" (~80%), "MasVnrType"(~60%), "FireplaceQu" (~50%), "LotFrontage" (~16%). The remaining 11 varables have missing values in less then 10% of records. Importantly, the distribution of missing values is consistent between the train and test datasets. At current stage, I have dropped the "PoolQC", 'Alley', 'MiscFeature', 'Fence', 'MasVnrType', 'FireplaceQu' and 'Id' variables from both datasets and saved the updated versions as new csv files.
# 2. I analyzed the distribution of records in the train dataset, focusing on six features of interest, all of which showed significantly biased distribution. For Zoning Classification, the vast majority of records belong to RL (Residential Low Density) and RM (Residential Medium Density). Similarly, for Type of Sale, most transactions are categorized as WD (Warranty Deed - Conventional), and for Sale condition, "Normal" accounts for the majority of records. In contrast, the distributions of Type of Dwelling, Neighborhood, and Month sale (MM) are more varied. The top three dwelling types are 20 (1-STORY 1946 & NEWER ALL STYLES), 60 (2-STORY 1946 & NEWER) and 50 (1-1/2 STORY FINISHED ALL AGES). The most common neighborhoods are NAmes, CollgCr and OldTown. Interestingly, there is a clear seasonal trend in the sales data: June, July and May are the busiest months, while Feb, Jan and Dec see the fewest sales.
# 3. All six features of interest impact the sale price. Among Zoning Classes, FV(Floating Village Residential), RL(Residential Low Density) and RH(Residential High Density) are assocated with the highest prices. For Dwelling Types, the top three are 60(2-STORY 1946 & NEWER), 120(1-STORY PUD (Planned Unit Development) - 1946 & NEWER), 75(2-1/2 STORY ALL AGES). In terms of Neighborhood, NoRidge, NridgHt and StoneBr consistently have the highest porperty values. While the seasonal factor doesn't appear to significantly affect sale prices, the data shows that prices tend to peak in Sep, Nov and Dec and are lowest in June, May and April. Regarding Sale Types, New (Home just constructed and sold) and Con (Contract 15% Down payment regular terms) command higher prices than other categories. Notablly, homes classified under the Sale Condition "Partial" (Home was not completed when last assessed) have the highest sale prices, which contradicts common expectations. This finding is quite surprising ans unusual.
# 4. The data includes 25 Neighborhoods in Ames, IA, but many of these names do not match the 27 neighborhoods listed on the City of Ames Neighborhood Associations Map (https://www.cityofames.org/home/showpublisheddocument/52755/637050278030900000). Using Google Maps, we observed a clear geographical pattern between neighborboods with the highest and lowest sale prices. The top five neighborhoods with the highest sale prices are located in the northwest part of Ames, while the neighborhoods with the lowest sale prices are primarily distributed in the city's central area where the old town is situated, as well as in the southeast part of the city.
